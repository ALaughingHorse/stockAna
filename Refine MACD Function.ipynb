# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pandas_datareader.data as web
import graphviz
from Functions import *

% matplotlib inline
Psize = (30,20)

# %%
fb_df = pd.read_csv('Data/FB.csv')
fb = fb_df['Close']
fb = np.append(fb.values,[153.74])
fb_sum = get_rich(fb,day_num = 'max')
# Out:
# C:\Users\xma\Documents\stockAna\Functions.py:286: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=0,adjust=False,ignore_na=False).mean()
#   price_ema_12 = pd.ewma(price,span = 12,adjust = False)
# C:\Users\xma\Documents\stockAna\Functions.py:287: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=0,adjust=False,ignore_na=False).mean()
#   price_ema_26 = pd.ewma(price,span = 26, adjust = False)
# C:\Users\xma\Documents\stockAna\Functions.py:291: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   signal = pd.ewma(macd,span = 9, adjust = False)
# ...

# %%
fb_sum.cart_graph

# %% [markdown]
# ### CLX

# %%
clx_df = pd.read_csv('Data/CLX.csv')
clx = clx_df['Close']
clx_sum = get_rich(clx,day_num=100,Psize=(10,5))
# Out:
# C:\Users\xma\Documents\stockAna\Functions.py:286: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=12,min_periods=0,adjust=False,ignore_na=False).mean()
#   price_ema_12 = pd.ewma(price,span = 12,adjust = False)
# C:\Users\xma\Documents\stockAna\Functions.py:287: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=26,min_periods=0,adjust=False,ignore_na=False).mean()
#   price_ema_26 = pd.ewma(price,span = 26, adjust = False)
# C:\Users\xma\Documents\stockAna\Functions.py:291: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   signal = pd.ewma(macd,span = 9, adjust = False)
# ...

# %% [markdown]
# ### TSLA
